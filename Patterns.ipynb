# %%
n = 5
for i in range(n):
    for j in range(n):
        if i == 0 or i == n - 1 or j == 0 or j == n - 1:
            print("*", end="")
        else:
            print("*", end="")
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
n = 5
s = "Hello"
for i in range(n):
    for ch in s:
        for j in range(i,n):
            print(" ",end=" ")
        for j in range(1,i+2):
            print(ch,end=" ")
        for j in range(1,i+1):
                print(ch,end=" ")
        print()
# Out:
#           H
#           e
#           l
#           l
#           o
#         H H H
#         e e e
#         l l l
#         l l l
#         o o o
#       H H H H H
#       e e e e e
#       l l l l l
#       l l l l l
#       o o o o o
#     H H H H H H H
#     e e e e e e e
#     l l l l l l l
#     l l l l l l l
#     o o o o o o o
#   H H H H H H H H H
#   e e e e e e e e e
#   l l l l l l l l l
#   l l l l l l l l l
#   o o o o o o o o o

# %%
arr = [1,2,3,2,3,4,6,2,5,7,8,7,3,4,5,7,9]
target = int(input())
count = 0
for num in arr :
    if num == target:
        count += 1
print(f"The {target} is appear {count} times in list")
# Out:
# The 3 is appear 3 times in list
